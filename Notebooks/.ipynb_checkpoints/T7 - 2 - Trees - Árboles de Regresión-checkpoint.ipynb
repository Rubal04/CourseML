# %% [markdown]
# # Árboles de Regresión

# %%
import pandas as pd

# %%
data = pd.read_csv("/Users/Gullermo R/OneDrive/Documentos/GitHub/python-ml-course/datasets/boston/Boston.csv")
data.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
data.shape
# Out:
# (506, 14)

# %%
colnames = data.columns.values.tolist()
predictors = colnames[:13]
target = colnames[13]
X = data[predictors]
Y = data[target]

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
regtree = DecisionTreeRegressor(min_samples_split=30, min_samples_leaf=10, max_depth=5, random_state=0)

# %%
regtree.fit(X,Y)
# Out:
# DecisionTreeRegressor(max_depth=5, min_samples_leaf=10, min_samples_split=30,
#                       random_state=0)

# %%
preds = regtree.predict(data[predictors])

# %%
data["preds"] = preds

# %%
data[["preds", "medv"]]
# Out:
#          preds  medv
# 0    23.787500  24.0
# 1    23.787500  21.6
# 2    35.247826  34.7
# 3    35.247826  33.4
# 4    35.247826  36.2
# ..         ...   ...
# 501  23.787500  22.4
# 502  23.787500  20.6
# 503  28.978261  23.9
# 504  31.170000  22.0
# 505  23.787500  11.9
#
# [506 rows x 2 columns]

# %%
from sklearn.tree import export_graphviz
with open("/Users/Gullermo R/OneDrive/Documentos/GitHub/python-ml-course/notebooks/resources/boston_rtree.dot", "w") as dotfile:
    export_graphviz(regtree, out_file=dotfile, feature_names=predictors)
    dotfile.close()
    
import os
from graphviz import Source
file = open("/Users/Gullermo R/OneDrive/Documentos/GitHub/python-ml-course/notebooks/resources/boston_rtree.dot", "r")
text = file.read()
Source(text)

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
import numpy as np

# %%
cv = KFold(n_splits = X.shape[0], shuffle=True, random_state=1)
scores = cross_val_score(regtree, X, Y, scoring="neg_mean_squared_error", cv = cv, n_jobs=1)
print(scores)
score = np.mean(scores)
print(score)
# Out:
# [-2.03911146e+01 -1.28853178e-02 -1.27417958e+01 -3.25298596e+00
#  -2.37502003e-01 -7.13386831e+00 -1.48833518e+01 -4.53538109e+01
#  -1.89057729e+01 -1.43567892e+00 -7.79482185e-03 -1.47617729e-01
#  -6.98941406e+00 -6.45477539e+00 -8.65606473e-01 -5.94480539e+01
#  -1.66388102e+01 -2.57293817e+01 -9.94237481e-02 -3.39432892e-01
#  -2.51430612e+01 -2.77350592e+00 -5.10575207e+01 -1.65849603e+00
#  -7.20711634e+01 -2.72633856e+00 -3.19470699e-01 -8.14777279e+00
#  -4.26636147e+00 -2.63495944e+00 -9.94237481e-02 -2.51843100e+00
#  -2.57293817e+01 -1.96000000e+00 -1.61879360e+01 -1.75424608e+01
#  -5.65890902e+00 -9.90929752e-01 -4.13129259e+00 -3.61731139e+00
#  -1.43567892e+00 -9.70518951e+00 -4.13728612e+01 -5.98941399e-01
#  -5.15017301e-01 -2.11834793e+02 -2.57293817e+01 -1.67474048e+00
#  -1.51358050e+01 -3.02936228e+00 -7.38037190e-01 -1.35424000e+01
#  -2.52004000e+01 -1.21120187e+01 -3.84400000e+01 -2.56576901e+00
# ...

# %%
list(zip(predictors,regtree.feature_importances_))
# Out:
# [('crim', 0.032184533425691254),
#  ('zn', 0.0),
#  ('indus', 0.0),
#  ('chas', 0.0),
#  ('nox', 0.016195328299152056),
#  ('rm', 0.6341876193016562),
#  ('age', 0.014165271650613091),
#  ('dis', 0.0),
#  ('rad', 0.0),
#  ('tax', 0.0),
#  ('ptratio', 0.009620458196377114),
#  ('black', 0.0),
#  ('lstat', 0.2936467891265104)]

# %% [markdown]
# ## Random Forests

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
forest = RandomForestRegressor(n_jobs=2, oob_score=True, n_estimators=10000)
forest.fit(X,Y)
# Out:
# RandomForestRegressor(n_estimators=10000, n_jobs=2, oob_score=True)

# %%
data["rforest_pred"]= forest.oob_prediction_
data[["rforest_pred", "medv"]]
# Out:
#      rforest_pred  medv
# 0       28.505418  24.0
# 1       22.606529  21.6
# 2       34.551933  34.7
# 3       34.721996  33.4
# 4       34.303317  36.2
# ..            ...   ...
# 501     24.206908  22.4
# 502     18.852908  20.6
# 503     27.720306  23.9
# 504     26.096063  22.0
# 505     20.857923  11.9
#
# [506 rows x 2 columns]

# %%
data["rforest_error2"] = (data["rforest_pred"]-data["medv"])**2
sum(data["rforest_error2"])/len(data)
# Out:
# 10.232546267752026

# %%
forest.oob_score_
# Out:
# 0.8787893856155427
